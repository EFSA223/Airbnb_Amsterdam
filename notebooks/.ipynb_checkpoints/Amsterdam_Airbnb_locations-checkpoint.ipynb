# %% [markdown]
# # Airbnb locations in Amsterdam

# %% [markdown]
# This project gives the housing locations that are offered by Airbnb in Amsterdam, The Netherlands.

# %% [markdown]
# Tools used to perform the data munging of this project:
# Miniconda, Python 3.x, Jupyter Notebook, Pandas, GeoPandas with dependacies.

# %% [markdown]
# This Jupyter Notebook objective are:
#     - load, downloaded dataset in the notebook
#     - Analyse the dataset with the available methods
#     - remove unnecesary columns, using the drop method
#     - create the data geometry
#     - write the cleaned data to file

# %% [markdown]
# Link of the dataset: (http://insideairbnb.com/index.html).<br>
# Authored by: Etienne Sambo.

# %% [markdown]
# ## Packages and Data import

# %%
# Import package into notebook

# %matplotlib inline

import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import fiona

import warnings #suppresing warning, keep notebook looking clean!
warnings. simplefilter(action='ignore')

# %% [markdown]
# Use the **.read_csv() method** to request the CSV file ('listing.csv') and read it into the notebook and assign it to a variable named df.

# %%
df = pd.read_csv('../notebooks/data/listings_raw.csv');

# %% [markdown]
# ## Explore and analyse dataset

# %%
# Print a concise summary of a DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20337 entries, 0 to 20336
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(31), int64(25), object(50)
# memory usage: 16.4+ MB

# %% [markdown]
# At first glance, this is a large data set with 106 columns.<br>
# Let's read the first 5 and last 5 lines to see what kind of data we have here. Using **.head()** and **.tail() methods**.

# %%
# Read the first five records of teh dataset!
df.head()
# Out:
#       id                         listing_url       scrape_id  last_scraped  \
# 0   2818   https://www.airbnb.com/rooms/2818  20190708161114         43655
# 1  20168  https://www.airbnb.com/rooms/20168  20190708161114         43655
# 2  25428  https://www.airbnb.com/rooms/25428  20190708161114         43655
# 3  27886  https://www.airbnb.com/rooms/27886  20190708161114         43655
# 4  28871  https://www.airbnb.com/rooms/28871  20190708161114         43655
#
#                                                 name  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1       Studio with private bathroom in the centre 1
# 2    Lovely apt in City Centre (w.lift) near Jordaan
# 3  Romantic, stylish B&B houseboat in canal district
# 4                            Comfortable double room
#
#                                              summary  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1  Cozy studio on your own private floor, 100% in...
# 2                                                NaN
# 3  Stylish and romantic houseboat on fantastic hi...
# 4                                                NaN
#
#                                                space  \
# 0  I'm renting a bedroom (room overlooking the ga...
# 1  For those who like all facets of city life. In...
# 2  This nicely furnished, newly renovated apt  is...
# 3  For a romantic couple: A beautifully restored ...
# 4  In a monumental house right in the center of A...
#
#                                          description experiences_offered  \
# 0  Quiet Garden View Room & Super Fast WiFi I'm r...                none
# 1  Cozy studio on your own private floor, 100% in...                none
# 2  This nicely furnished, newly renovated apt  is...                none
# 3  Stylish and romantic houseboat on fantastic hi...                none
# 4  In a monumental house right in the center of A...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0  Indische Buurt ("Indies Neighborhood") is a ne...  ...                t
# 1  Located just in between famous central canals....  ...                f
# 2                                                NaN  ...                f
# 3         Central, quiet, safe, clean and beautiful.  ...                t
# 4                                                NaN  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               2
# 2                               2
# 3                               1
# 4                               3
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            2
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            2
# 2                                            0
# 3                                            1
# 4                                            3
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               2.09
# 1                                            0               2.45
# 2                                            0               0.17
# 3                                            0               2.14
# 4                                            0               2.56
#
# [5 rows x 106 columns]

# %%
# Read the last five records of teh dataset!
df.tail()
# Out:
#              id                            listing_url       scrape_id  \
# 20332  36495072  https://www.airbnb.com/rooms/36495072  20190708161114
# 20333  36497290  https://www.airbnb.com/rooms/36497290  20190708161114
# 20334  36497781  https://www.airbnb.com/rooms/36497781  20190708161114
# 20335  36498483  https://www.airbnb.com/rooms/36498483  20190708161114
# 20336  36500242  https://www.airbnb.com/rooms/36500242  20190708161114
#
#        last_scraped                                               name  \
# 20332         43655  Apartment Amsterdam next to city center (1 per...
# 20333         43655           Penthouse in Watergraafsmeer (Amsterdam)
# 20334         43655  Cozy room in Amsterdam with nice (Hidden by Ai...
# 20335         43655        City apartment near centre, water and beach
# 20336         43655                  Room in lovely central  apartment
#
#                                                  summary  \
# 20332  Quiet apartment, close to the city center. Nex...
# 20333  Penthouse op hoek met lichtinval vanuit 3 zijd...
# 20334                                                NaN
# 20335  Spacious and bright apartment near waterfront ...
# 20336  Room in a lovely 3 floor apartment right in th...
#
#                                                    space  \
# 20332                                                NaN
# 20333  De luxueuze keuken beschikt over Italiaans (Do...
# 20334                                                NaN
# 20335  Enjoy your stay in our relaxed and comfortable...
# 20336                                                NaN
#
#                                              description experiences_offered  \
# 20332  Quiet apartment, close to the city center. Nex...                none
# 20333  Penthouse op hoek met lichtinval vanuit 3 zijd...                none
# 20334                                                NaN                none
# 20335  Spacious and bright apartment near waterfront ...                none
# 20336  Room in a lovely 3 floor apartment right in th...                none
#
#                                    neighborhood_overview  ...  \
# 20332                                                NaN  ...
# 20333  Op de plek van het (voormalige) beroemde Stadi...  ...
# 20334                                                NaN  ...
# 20335                                                NaN  ...
# 20336                                                NaN  ...
#
#       instant_bookable is_business_travel_ready cancellation_policy  \
# 20332                f                        f            flexible
# 20333                t                        f            flexible
# 20334                f                        f            flexible
# 20335                t                        f            flexible
# 20336                f                        f            flexible
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 20332                             f                                f
# 20333                             f                                f
# 20334                             f                                f
# 20335                             f                                f
# 20336                             f                                f
#
#        calculated_host_listings_count  \
# 20332                               2
# 20333                               1
# 20334                               1
# 20335                               1
# 20336                               1
#
#        calculated_host_listings_count_entire_homes  \
# 20332                                            2
# 20333                                            1
# 20334                                            0
# 20335                                            1
# 20336                                            0
#
#       calculated_host_listings_count_private_rooms  \
# 20332                                            0
# 20333                                            0
# 20334                                            1
# 20335                                            0
# 20336                                            1
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 20332                                            0                NaN
# 20333                                            0                NaN
# 20334                                            0                NaN
# 20335                                            0                NaN
# 20336                                            0                NaN
#
# [5 rows x 106 columns]

# %%
# Show the columns of the dataframe.
cols = list(df.columns)
cols
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %% [markdown]
# # Drop columns!

# %%
# drop all selected columns
df = df.drop([
 'listing_url',
 'scrape_id',
 'last_scraped',
 'summary',
 'space',
 'experiences_offered',
 'neighborhood_overview',
 'notes',
 'transit',
 'access',
 'interaction',
 'house_rules',
 'thumbnail_url',
 'medium_url',
 'picture_url',
 'xl_picture_url',
 'host_url',
 'host_about',
 'host_response_time',
 'host_response_rate',
 'host_acceptance_rate',
 'host_is_superhost',
 'host_thumbnail_url',
 'host_picture_url',
 'host_listings_count',
 'host_total_listings_count',
 'host_verifications',
 'host_has_profile_pic',
 'host_identity_verified',
 'market',
 'neighbourhood_group_cleansed',
 'city',   
 'smart_location',
 'is_location_exact',
 'accommodates',
 'bathrooms',
 'bedrooms',
 'beds',
 'bed_type',
 'amenities',
 'weekly_price',
 'monthly_price',
 'security_deposit',
 'cleaning_fee',
 'guests_included',
 'extra_people',
 'minimum_nights',
 'maximum_nights',
 'minimum_minimum_nights',
 'maximum_minimum_nights',
 'minimum_maximum_nights',
 'maximum_maximum_nights',
 'minimum_nights_avg_ntm',
 'maximum_nights_avg_ntm',
 'calendar_updated',
 'has_availability',
 'availability_30',
 'availability_60',
 'availability_90',
 'availability_365',
 'calendar_last_scraped',
 'number_of_reviews',
 'number_of_reviews_ltm',
 'first_review',
 'review_scores_rating',
 'review_scores_accuracy',
 'review_scores_cleanliness',
 'review_scores_checkin',
 'review_scores_communication',
 'review_scores_location',
 'review_scores_value',
 'requires_license',
 'license',
 'jurisdiction_names',
 'instant_bookable',
 'is_business_travel_ready',
 'require_guest_profile_picture',
 'require_guest_phone_verification',
 'calculated_host_listings_count',
 'calculated_host_listings_count_entire_homes',
 'calculated_host_listings_count_private_rooms',
 'calculated_host_listings_count_shared_rooms',
 'reviews_per_month'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20337 entries, 0 to 20336
# Data columns (total 23 columns):
# id                        20337 non-null int64
# name                      20302 non-null object
# description               20149 non-null object
# host_id                   20337 non-null int64
# host_name                 20313 non-null object
# host_since                20313 non-null float64
# host_location             20273 non-null object
# host_neighbourhood        14493 non-null object
# street                    20337 non-null object
# neighbourhood             19511 non-null object
# neighbourhood_cleansed    20337 non-null object
# state                     20141 non-null object
# zipcode                   19471 non-null object
# country_code              20337 non-null object
# country                   20337 non-null object
# latitude                  20337 non-null float64
# longitude                 20337 non-null float64
# property_type             20337 non-null object
# room_type                 20337 non-null object
# square_feet               389 non-null float64
# price                     20337 non-null int64
# last_review               17797 non-null float64
# cancellation_policy       20337 non-null object
# dtypes: float64(5), int64(3), object(15)
# memory usage: 3.6+ MB

# %%
geometry  = [Point(xy) for xy in zip(df.longitude, df.latitude)]

# %%
crs = {'init': 'epgs:4326'}
gdf = gpd.GeoDataFrame(df, crs=crs, geometry=geometry)

# %%
gdf
# Out:
#              id                                               name  \
# 0          2818           Quiet Garden View Room & Super Fast WiFi
# 1         20168       Studio with private bathroom in the centre 1
# 2         25428    Lovely apt in City Centre (w.lift) near Jordaan
# 3         27886  Romantic, stylish B&B houseboat in canal district
# 4         28871                            Comfortable double room
# ...         ...                                                ...
# 20332  36495072  Apartment Amsterdam next to city center (1 per...
# 20333  36497290           Penthouse in Watergraafsmeer (Amsterdam)
# 20334  36497781  Cozy room in Amsterdam with nice (Hidden by Ai...
# 20335  36498483        City apartment near centre, water and beach
# 20336  36500242                  Room in lovely central  apartment
#
#                                              description    host_id  \
# 0      Quiet Garden View Room & Super Fast WiFi I'm r...       3159
# 1      Cozy studio on your own private floor, 100% in...      59484
# 2      This nicely furnished, newly renovated apt  is...      56142
# 3      Stylish and romantic houseboat on fantastic hi...      97647
# 4      In a monumental house right in the center of A...     124245
# ...                                                  ...        ...
# 20332  Quiet apartment, close to the city center. Nex...    4008095
# 20333  Penthouse op hoek met lichtinval vanuit 3 zijd...   46369523
# 20334                                                NaN    4263291
# 20335  Spacious and bright apartment near waterfront ...  274421872
# 20336  Room in a lovely 3 floor apartment right in th...  230985669
#
#         host_name  host_since                              host_location  \
# 0          Daniel     39715.0  Amsterdam, Noord-Holland, The Netherlands
# 1       Alexander     40149.0  Amsterdam, Noord-Holland, The Netherlands
# 2            Joan     40137.0          New York, New York, United States
# 3            Flip     40260.0  Amsterdam, Noord-Holland, The Netherlands
# 4           Edwin     40311.0  Amsterdam, Noord-Holland, The Netherlands
# ...           ...         ...                                        ...
# 20332  Aleksandra     41211.0  Amsterdam, Noord-Holland, The Netherlands
# 20333       Elwin     42289.0      Amsterdam, North Holland, Netherlands
# 20334      Didier     41240.0            London, England, United Kingdom
# 20335       Robin     43654.0      Amsterdam, North Holland, Netherlands
# 20336     Lorenzo     43450.0                     Milan, Lombardy, Italy
#
#         host_neighbourhood                                 street  \
# 0           Indische Buurt  Amsterdam, North Holland, Netherlands
# 1           Grachtengordel  Amsterdam, North Holland, Netherlands
# 2           Grachtengordel  Amsterdam, North Holland, Netherlands
# 3      Westelijke Eilanden  Amsterdam, North Holland, Netherlands
# 4        Amsterdam Centrum  Amsterdam, North Holland, Netherlands
# ...                    ...                                    ...
# 20332       Indische Buurt  Amsterdam, North Holland, Netherlands
# 20333      Watergraafsmeer  Amsterdam, Noord-Holland, Netherlands
# 20334                  NaN  Amsterdam, Noord-Holland, Netherlands
# 20335                 Oost  Amsterdam, Noord-Holland, Netherlands
# 20336            De Wallen  Amsterdam, Noord-Holland, Netherlands
#
#              neighbourhood  ...      country  latitude longitude  \
# 0           Indische Buurt  ...  Netherlands  52.36575   4.94142
# 1           Grachtengordel  ...  Netherlands  52.36509   4.89354
# 2           Grachtengordel  ...  Netherlands  52.37297   4.88339
# 3      Westelijke Eilanden  ...  Netherlands  52.38673   4.89208
# 4        Amsterdam Centrum  ...  Netherlands  52.36719   4.89092
# ...                    ...  ...          ...       ...       ...
# 20332       Indische Buurt  ...  Netherlands  52.36199   4.92867
# 20333      Watergraafsmeer  ...  Netherlands  52.34480   4.94942
# 20334  Slotermeer-Zuidwest  ...  Netherlands  52.38431   4.81645
# 20335                  NaN  ...  Netherlands  52.35116   5.00162
# 20336    Amsterdam Centrum  ...  Netherlands  52.37075   4.89750
#
#       property_type        room_type  square_feet  price last_review  \
# 0         Apartment     Private room          NaN     59     43644.0
# 1         Townhouse     Private room          NaN     80     43654.0
# 2         Apartment  Entire home/apt          NaN    125     43596.0
# 3         Houseboat     Private room          NaN    150     43647.0
# 4         Apartment     Private room          NaN     75     43648.0
# ...             ...              ...          ...    ...         ...
# 20332     Apartment  Entire home/apt          NaN     80         NaN
# 20333     Apartment  Entire home/apt          NaN    350         NaN
# 20334     Apartment     Private room          NaN     30         NaN
# 20335     Apartment  Entire home/apt          NaN    125         NaN
# 20336     Apartment     Private room          NaN    140         NaN
#
#                cancellation_policy  \
# 0      strict_14_with_grace_period
# 1      strict_14_with_grace_period
# 2      strict_14_with_grace_period
# 3      strict_14_with_grace_period
# 4                         moderate
# ...                            ...
# 20332                     flexible
# 20333                     flexible
# 20334                     flexible
# 20335                     flexible
# 20336                     flexible
#
#                                           geometry
# 0                         POINT (4.94142 52.36575)
# 1                         POINT (4.89354 52.36509)
# 2                         POINT (4.88339 52.37297)
# 3                         POINT (4.89208 52.38673)
# 4               POINT (4.890919999999999 52.36719)
# ...                                            ...
# 20332  POINT (4.928669999999999 52.36199000000001)
# 20333                      POINT (4.94942 52.3448)
# 20334                     POINT (4.81645 52.38431)
# 20335                     POINT (5.00162 52.35116)
# 20336                      POINT (4.8975 52.37075)
#
# [20337 rows x 24 columns]

# %%
gdf.to_csv('../map/data/listings_cleaned.csv', index=False) # write DataFrame to CSV file

# %%
gdf.to_file('../map/data/SHP') # write DataFrame to SHP file

# %%
type(gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
gdf.bounds
# Out:
#           minx      miny     maxx      maxy
# 0      4.94142  52.36575  4.94142  52.36575
# 1      4.89354  52.36509  4.89354  52.36509
# 2      4.88339  52.37297  4.88339  52.37297
# 3      4.89208  52.38673  4.89208  52.38673
# 4      4.89092  52.36719  4.89092  52.36719
# ...        ...       ...      ...       ...
# 20332  4.92867  52.36199  4.92867  52.36199
# 20333  4.94942  52.34480  4.94942  52.34480
# 20334  4.81645  52.38431  4.81645  52.38431
# 20335  5.00162  52.35116  5.00162  52.35116
# 20336  4.89750  52.37075  4.89750  52.37075
#
# [20337 rows x 4 columns]
